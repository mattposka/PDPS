# %%
import glob
import numpy as np
import cv2
from skimage.morphology import closing,square

# %%
test_files = glob.glob('../data/testImages/*')

# %%
##imgCV2 = cv2.imread('../data/testImages/rapa_cam_02_2021-06-19_1100.png')
#imgCV2 = cv2.imread('../data/testImages/rapa_cam_02_2021-06-19_1100.png',cv2.IMREAD_GRAYSCALE)
#
#detector = cv2.SimpleBlobDetector()
#
#keypoints = detector.detect(imgCV2)

# %%
images = []
for f in test_files:
    images.append( cv2.imread(f) )

# %%
test_files[0]
# Out:
# '../data/testImages/rapa_cam_23_2021-03-25_2300.png'

# %%
#img = cv2.imread(test_files[0])
img = cv2.imread('../data/testImages/rapa_cam_11_2021-06-19_0000.png')

# %%
r,c,_ = img.shape
print( 'img.shape',img.shape )
#r,c = img.shape
square_size = np.min([r,c])

ss2 = square_size/2
r2 = r/2
rs = int(r2-ss2)
re = int(r2+ss2)
c2 = c/2
cs = int(c2-ss2)
ce = int(c2+ss2)
#a = imgCV2[rs:re,cs:ce,:]
a = img[rs:re,cs:ce]
print(a.shape)

a = cv2.resize(a,(256,256))
img = a
# Out:
# img.shape (2464, 3280, 3)
# (2464, 2464, 3)

# %%
resized_images = []
for i in images:
    resized_images.append( cv2.resize(i[rs:re,cs:ce],(256,256)) )

# %%
hsv_img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
hue = hsv_img[:,:,0]
sat = hsv_img[:,:,1]
val = hsv_img[:,:,2]

# %%
bgr_img = cv2.cvtColor(hsv_img,cv2.COLOR_HSV2BGR)
#cv2.imshow('img',bgr_img)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
ret_sat,thresh_sat = cv2.threshold( sat,70,255,cv2.THRESH_BINARY ) 
mask1 = cv2.bitwise_and( bgr_img,bgr_img,mask=thresh_sat )

cv2.imshow('mask1',mask1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
ret_val,thresh_val = cv2.threshold( val,118,255,cv2.THRESH_BINARY_INV ) 
#cv2.imshow('val inv thresh',thresh_val)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

mask2 = cv2.bitwise_and( mask1,mask1,mask=thresh_val )
#cv2.imshow('mask2',mask2)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
rgb_img = cv2.cvtColor(hsv_img,cv2.COLOR_HSV2RGB)
red = rgb_img[:,:,0]
green = rgb_img[:,:,1]
blue = rgb_img[:,:,2]

# %%
ret_r, thresh_r = cv2.threshold(red,97,255,cv2.THRESH_BINARY_INV)
mask3 = cv2.bitwise_and( mask2,mask2,mask=thresh_r )

# %%
ret_g, thresh_g = cv2.threshold(green,50,255,cv2.THRESH_BINARY_INV)
mask4 = cv2.bitwise_and( mask3,mask3,mask=thresh_g )

# %%
ret_b, thresh_b = cv2.threshold(blue,25,255,cv2.THRESH_BINARY_INV)
mask5 = cv2.bitwise_and( mask4,mask4,mask=thresh_b )

# %%
masked_images = []
for i in resized_images:
    hsv_img = cv2.cvtColor(i,cv2.COLOR_BGR2HSV)
    hue = hsv_img[:,:,0]
    sat = hsv_img[:,:,1]
    val = hsv_img[:,:,2]
    
    bgr_img = cv2.cvtColor(hsv_img,cv2.COLOR_HSV2BGR)
    
    ret_sat,thresh_sat = cv2.threshold( sat,70,255,cv2.THRESH_BINARY ) 
    mask1 = cv2.bitwise_and( bgr_img,bgr_img,mask=thresh_sat )
    
    ret_val,thresh_val = cv2.threshold( val,118,255,cv2.THRESH_BINARY_INV ) 
    mask2 = cv2.bitwise_and( mask1,mask1,mask=thresh_val )
    
    rgb_img = cv2.cvtColor(hsv_img,cv2.COLOR_HSV2RGB)
    red = rgb_img[:,:,0]
    green = rgb_img[:,:,1]
    blue = rgb_img[:,:,2]
    
    ret_r, thresh_r = cv2.threshold(red,97,255,cv2.THRESH_BINARY_INV)
    mask3 = cv2.bitwise_and( mask2,mask2,mask=thresh_r )
    ret_g, thresh_g = cv2.threshold(green,50,255,cv2.THRESH_BINARY_INV)
    mask4 = cv2.bitwise_and( mask3,mask3,mask=thresh_g )
    ret_b, thresh_b = cv2.threshold(blue,25,255,cv2.THRESH_BINARY_INV)
    mask5 = cv2.bitwise_and( mask4,mask4,mask=thresh_b )
    
    masked_images.append(mask5)

# %%
for m in masked_images:
    cv2.imshow('mask5',m)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
#cv2.imshow('mask5',mask5)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
# only keep the largest connected component
closed_mask = closing( mask,square(3) )

labeled_img = label(closed_mask, connectivity=2)
# leaf area should be the second largest number, with background being the most common
mode_label,count = ss.mode( labeled_img,axis=None )
# remove the most common label here
labeled_img_filtered = np.where( labeled_img==mode_label,np.nan,labeled_img )
mode_label,count = ss.mode( labeled_img_filtered,axis=None,nan_policy='omit' )
leaf_label = mode_label
leaf_mask = np.where( labeled_img==leaf_label,True,False )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-1fe9d3679ac7> in <module>
#       1 # only keep the largest connected component
# ----> 2 closed_mask = closing( mask,square(3) )
#       3
#       4 labeled_img = label(closed_mask, connectivity=2)
#       5 # leaf area should be the second largest number, with background being the most common
#
# NameError: name 'mask' is not defined

# %%
#im = cv2.imread('extract_blue.jpg')
#imgray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
#imgray = cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)
#ret, thresh = cv2.threshold(imgray, 127, 255, 0)
cv2.imshow('thresh',a)
#cv2.imshow('thresh',imgray)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# get contours
contours, hierarchy = cv2.findContours(imgray, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# %%
contours_area = []
# calculate area and filter into new array
for con in contours:
    area = cv2.contourArea(con)
    if 100 < area < 10000:
        contours_area.append(con)

# %%
len( contours_area )
# Out:
# 0

# %%
import cv2
import numpy as np

def nothing(x):
    pass

# Load image
#image = cv2.imread('1.jpg')
image = mask2

# Create a window
cv2.namedWindow('image')

# Create trackbars for color change
# Hue is from 0-179 for Opencv
cv2.createTrackbar('RMin', 'image', 0, 255, nothing)
cv2.createTrackbar('GMin', 'image', 0, 255, nothing)
cv2.createTrackbar('BMin', 'image', 0, 255, nothing)
cv2.createTrackbar('RMax', 'image', 0, 255, nothing)
cv2.createTrackbar('GMax', 'image', 0, 255, nothing)
cv2.createTrackbar('BMax', 'image', 0, 255, nothing)

# Set default value for Max HSV trackbars
cv2.setTrackbarPos('RMax', 'image', 255)
cv2.setTrackbarPos('GMax', 'image', 255)
cv2.setTrackbarPos('BMax', 'image', 255)

# Initialize HSV min/max values
rMin = gMin = bMin = rMax = gMax = bMax = 0
prMin = pgMin = pbMin = prMax = pgMax = pbMax = 0

while(1):
    # Get current positions of all trackbars
    rMin = cv2.getTrackbarPos('RMin', 'image')
    gMin = cv2.getTrackbarPos('GMin', 'image')
    bMin = cv2.getTrackbarPos('BMin', 'image')
    rMax = cv2.getTrackbarPos('RMax', 'image')
    gMax = cv2.getTrackbarPos('GMax', 'image')
    bMax = cv2.getTrackbarPos('BMax', 'image')

    # Set minimum and maximum HSV values to display
    lower = np.array([rMin, gMin, bMin])
    upper = np.array([rMax, gMax, bMax])

    # Convert to HSV format and color threshold
    rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    mask = cv2.inRange(rgb, lower, upper)
    result = cv2.bitwise_and(image, image, mask=mask)

    # Print if there is a change in HSV value
    if((prMin != rMin) | (pgMin != gMin) | (pbMin != bMin) | (prMax != rMax) | (pgMax != gMax) | (pbMax != bMax) ):
        print("(rMin = %d , gMin = %d, bMin = %d), (rMax = %d , gMax = %d, bMax = %d)" % (rMin , gMin , bMin, rMax, gMax , bMax))
        prMin = rMin
        pgMin = gMin
        pbMin = bMin
        prMax = rMax
        pgMax = gMax
        pbMax = bMax

    # Display result image
    cv2.imshow('image', result)
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()
# Out:
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 1 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 4 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 5 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 7 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 8 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 9 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 11 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 14 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 16 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 18 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 19 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 20 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 23 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 24 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 26 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 27 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 28 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 30 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 31 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 32 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 34 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 35 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 37 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 38 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 39 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 41 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 42 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 43 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 45 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 46 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 47 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 48 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 49 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 50 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 51 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 52 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 53 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 54 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 55 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 57 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 59 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 60 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 62 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 63 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 66 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 68 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 69 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 70 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 72 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 73 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 74 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 78 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 80 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 81 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 84 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 87 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 88 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 89 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 90 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 91 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 93 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 95 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 97 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 99 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 100 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 101 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 104 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 106 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 107 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 108 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 111 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 112 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 113 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 114 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 115 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 116 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 118 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 119 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 120 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 122 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 125 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 126 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 124 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 122 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 120 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 118 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 116 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 114 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 113 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 112 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 110 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 106 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 103 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 101 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 100 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 99 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 97 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 96 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 95 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 94 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 93 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 91 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 90 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 89 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 87 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 86 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 85 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 83 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 81 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 80 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 79 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 78 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 76 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 74 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 73 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 72 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 70 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 69 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 68 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 67 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 64 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 59 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 57 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 55 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 54 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 53 , gMin = 0, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 53 , gMin = 1, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 53 , gMin = 5, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 53 , gMin = 7, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 53 , gMin = 8, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 53 , gMin = 10, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 53 , gMin = 12, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 53 , gMin = 14, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 53 , gMin = 16, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 53 , gMin = 20, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 53 , gMin = 22, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 53 , gMin = 23, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 53 , gMin = 24, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 53 , gMin = 26, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 53 , gMin = 27, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 53 , gMin = 29, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 53 , gMin = 30, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 53 , gMin = 32, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 53 , gMin = 33, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 53 , gMin = 35, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 53 , gMin = 36, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 53 , gMin = 37, bMin = 0), (rMax = 255 , gMax = 255, bMax = 255)
# (rMin = 53 , gMin =
bMin = 5), (rMax = 97 , gMax = 50, bMax = 23)
# (rMin = 0 , gMin = 11, bMin = 5), (rMax = 97 , gMax = 50, bMax = 23)
# (rMin = 0 , gMin = 12, bMin = 5), (rMax = 97 , gMax = 50, bMax = 23)
# (rMin = 0 , gMin = 14, bMin = 5), (rMax = 97 , gMax = 50, bMax = 23)
# (rMin = 0 , gMin = 8, bMin = 5), (rMax = 97 , gMax = 50, bMax = 23)
# (rMin = 0 , gMin = 3, bMin = 5), (rMax = 97 , gMax = 50, bMax = 23)
# (rMin = 0 , gMin = 0, bMin = 5), (rMax = 97 , gMax = 50, bMax = 23)
# (rMin = 0 , gMin = 0, bMin = 3), (rMax = 97 , gMax = 50, bMax = 23)
# (rMin = 0 , gMin = 0, bMin = 2), (rMax = 97 , gMax = 50, bMax = 23)
# (rMin = 0 , gMin = 0, bMin = 1), (rMax = 97 , gMax = 50, bMax = 23)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 23)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 25)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 32)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 34)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 36)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 39)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 41)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 42)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 45)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 46)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 45)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 43)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 42)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 41)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 38)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 37)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 36)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 35)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 34)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 32)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 31)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 30)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 29)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 28)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 27)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 26)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 28)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 29)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 30)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 31)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 30)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 29)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 28)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 26)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 24)
# (rMin = 0 , gMin = 0, bMin = 0), (rMax = 97 , gMax = 50, bMax = 25)

# %%
import cv2
import numpy as np

def nothing(x):
    pass

# Load image
#image = cv2.imread('1.jpg')
image = a

# Create a window
cv2.namedWindow('image')

# Create trackbars for color change
# Hue is from 0-179 for Opencv
cv2.createTrackbar('HMin', 'image', 0, 179, nothing)
cv2.createTrackbar('SMin', 'image', 0, 255, nothing)
cv2.createTrackbar('VMin', 'image', 0, 255, nothing)
cv2.createTrackbar('HMax', 'image', 0, 179, nothing)
cv2.createTrackbar('SMax', 'image', 0, 255, nothing)
cv2.createTrackbar('VMax', 'image', 0, 255, nothing)

# Set default value for Max HSV trackbars
cv2.setTrackbarPos('HMax', 'image', 179)
cv2.setTrackbarPos('SMax', 'image', 255)
cv2.setTrackbarPos('VMax', 'image', 255)

# Initialize HSV min/max values
hMin = sMin = vMin = hMax = sMax = vMax = 0
phMin = psMin = pvMin = phMax = psMax = pvMax = 0

while(1):
    # Get current positions of all trackbars
    hMin = cv2.getTrackbarPos('HMin', 'image')
    sMin = cv2.getTrackbarPos('SMin', 'image')
    vMin = cv2.getTrackbarPos('VMin', 'image')
    hMax = cv2.getTrackbarPos('HMax', 'image')
    sMax = cv2.getTrackbarPos('SMax', 'image')
    vMax = cv2.getTrackbarPos('VMax', 'image')

    # Set minimum and maximum HSV values to display
    lower = np.array([hMin, sMin, vMin])
    upper = np.array([hMax, sMax, vMax])

    # Convert to HSV format and color threshold
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(hsv, lower, upper)
    result = cv2.bitwise_and(image, image, mask=mask)

    # Print if there is a change in HSV value
    if((phMin != hMin) | (psMin != sMin) | (pvMin != vMin) | (phMax != hMax) | (psMax != sMax) | (pvMax != vMax) ):
        print("(hMin = %d , sMin = %d, vMin = %d), (hMax = %d , sMax = %d, vMax = %d)" % (hMin , sMin , vMin, hMax, sMax , vMax))
        phMin = hMin
        psMin = sMin
        pvMin = vMin
        phMax = hMax
        psMax = sMax
        pvMax = vMax

    # Display result image
    cv2.imshow('image', result)
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()
# Out:
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 1, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 3, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 4, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 6, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 7, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 10, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 13, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 18, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 22, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 26, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 27, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 29, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 30, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 32, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 33, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 34, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 36, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 38, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 40, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 41, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 43, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 44, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 47, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 49, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 50, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 51, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 53, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 54, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 55, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 56, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 57, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 59, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 61, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 62, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 63, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 65, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 66, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 67, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 71, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin =
vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 243, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 238, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 236, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 235, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 234, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 230, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 228, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 226, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 225, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 223, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 222, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 221, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 220, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 219, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 218, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 217, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 215, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 214, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 212, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 211, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 208, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 206, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 205, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 203, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 202, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 201, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 199, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 198, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 197, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 196, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 195, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 194, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 193, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 192, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 195, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 196, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 197, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 198, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 199, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 200, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 201, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 203, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 204, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 205, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 206, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 207, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 208, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 209, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 210, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 211, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 213, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 214, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 216, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 217, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 218, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 219, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 220, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 221, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 222, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 223, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 225, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 226, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 227, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 228, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 230, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 231, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 232, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 234, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 235, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 238, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 239, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 240, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 241, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 243, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 244, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 252)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 249)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 245)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 242)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 238)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 232)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 226)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 224)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 223)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 221)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 220)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 218)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 217)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 216)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 214)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 213)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 212)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 210)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 209)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 207)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 206)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 205)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 203)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 202)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 201)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 200)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 198)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 197)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 194)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 192)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 191)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 190)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 188)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 187)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 182)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 181)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 179)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 178)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 176)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 175)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 174)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 172)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 169)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 166)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 165)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 164)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 163)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 161)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 160)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 159)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 157)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 156)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 154)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 153)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 150)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 149)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 147)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 146)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 145)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 143)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 142)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 141)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 139)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 138)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 136)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 137)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 139)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 140)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 141)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 142)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 143)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 146)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 147)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 149)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 150)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 153)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 154)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 156)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 158)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 159)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 160)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 161)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 163)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 164)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 165)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 166)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 167)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 169)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 172)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 174)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 176)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 177)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 179)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 180)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 181)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 183)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 184)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 185)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 187)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 190)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 192)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 194)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 195)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 196)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 198)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 199)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 201)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 202)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 203)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 204)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 205)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 207)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 208)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 210)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 211)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 212)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 214)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 215)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 216)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 218)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 219)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 221)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 222)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 223)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 225)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 226)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 227)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 229)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 230)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 232)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 233)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 236)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 237)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 238)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 239)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 240)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 241)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 243)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 244)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 245)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 246)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 247)
# (hMin = 0 , sMin = 121, vMin = 62), (hMax = 179 , sMax = 245, vMax = 249)

# %%
#cv2.imshow('a',a)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
# Setup SimpleBlobDetector parameters.
params = cv2.SimpleBlobDetector_Params()

# Change thresholds
#params.minThreshold = 10;
#params.maxThreshold = 200;

# Filter by Area.
#params.filterByArea = True
#params.minArea = 500

# Filter by Circularity
#params.filterByCircularity = True
#params.minCircularity = 0.1

# Filter by Convexity
#params.filterByConvexity = True
#params.minConvexity = 0.87

# Filter by Inertia
#params.filterByInertia = True
#params.minInertiaRatio = 0.1

# Create a detector with the parameters
detector = cv2.SimpleBlobDetector_create(params)

# %%
#detector = cv2.SimpleBlobDetector()

# %%
#keypoints = detector.detect(a)

# %%
#detector = cv2.SimpleBlobDetector()

keypoints = detector.detect(mask2)

# Draw detected blobs as red circles.
# cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS ensures the size of the circle corresponds to the size of blob
im_with_keypoints = cv2.drawKeypoints(mask2, 
                                      keypoints, 
                                      np.array([]), 
                                      (0,0,255), 
                                      cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

# Show keypoints
cv2.imshow("Keypoints", im_with_keypoints)
cv2.waitKey(0)
cv2.destroyAllWindows()
