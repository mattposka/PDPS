# %%
import glob
import numpy as np
import cv2
from skimage.morphology import closing,square

# %%
test_files = glob.glob('../data/testImages/*')

# %%
##imgCV2 = cv2.imread('../data/testImages/rapa_cam_02_2021-06-19_1100.png')
#imgCV2 = cv2.imread('../data/testImages/rapa_cam_02_2021-06-19_1100.png',cv2.IMREAD_GRAYSCALE)
#
#detector = cv2.SimpleBlobDetector()
#
#keypoints = detector.detect(imgCV2)

# %%
#images = []
#for f in test_files:
#    imagesCV2.append( cv2.imread(f) )

# %%
test_files[0]
# Out:
# '../data/testImages/rapa_cam_23_2021-03-25_2300.png'

# %%
#img = cv2.imread(test_files[0])
img = cv2.imread('../data/testImages/rapa_cam_02_2021-06-20_0700.png')

# %%
#cv2.imshow('img',img)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#cv2.imshow('gray',img_gray)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

hsv_img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
hue = hsv_img[:,:,0]
sat = hsv_img[:,:,1]
val = hsv_img[:,:,2]

ret_sat,thresh_sat = cv2.threshold( sat,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU ) 
ret_hue,thresh_hue = cv2.threshold( hue,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU ) 
mask = cv2.bitwise_and( thresh_hue,thresh_sat,mask=None )
    
# only keep the largest connected component
closed_mask = closing( mask,square(3) )

labeled_img = label(closed_mask, connectivity=2)
# leaf area should be the second largest number, with background being the most common
mode_label,count = ss.mode( labeled_img,axis=None )
# remove the most common label here
labeled_img_filtered = np.where( labeled_img==mode_label,np.nan,labeled_img )
mode_label,count = ss.mode( labeled_img_filtered,axis=None,nan_policy='omit' )
leaf_label = mode_label
leaf_mask = np.where( labeled_img==leaf_label,True,False )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-abcd3e7dcf27> in <module>
#      16 closed_mask = closing( mask,square(3) )
#      17
# ---> 18 labeled_img = label(closed_mask, connectivity=2)
#      19 # leaf area should be the second largest number, with background being the most common
#      20 mode_label,count = ss.mode( labeled_img,axis=None )
#
# NameError: name 'label' is not defined

# %%
r,c,_ = img.shape
print( 'img.shape',img.shape )
#r,c = img.shape
square_size = np.min([r,c])

ss2 = square_size/2
r2 = r/2
rs = int(r2-ss2)
re = int(r2+ss2)
c2 = c/2
cs = int(c2-ss2)
ce = int(c2+ss2)
#a = imgCV2[rs:re,cs:ce,:]
a = img[rs:re,cs:ce]
print(a.shape)

a = cv2.resize(a,(256,256))
# Out:
# img.shape (2464, 3280, 3)
# (2464, 2464, 3)

# %%
#im = cv2.imread('extract_blue.jpg')
#imgray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
#imgray = cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)
#ret, thresh = cv2.threshold(imgray, 127, 255, 0)
cv2.imshow('thresh',a)
#cv2.imshow('thresh',imgray)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# get contours
contours, hierarchy = cv2.findContours(imgray, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# %%
contours_area = []
# calculate area and filter into new array
for con in contours:
    area = cv2.contourArea(con)
    if 100 < area < 10000:
        contours_area.append(con)

# %%
len( contours_area )
# Out:
# 0

# %%
import cv2
import numpy as np

def nothing(x):
    pass

# Load image
#image = cv2.imread('1.jpg')
image = a

# Create a window
cv2.namedWindow('image')

# Create trackbars for color change
# Hue is from 0-179 for Opencv
cv2.createTrackbar('HMin', 'image', 0, 179, nothing)
cv2.createTrackbar('SMin', 'image', 0, 255, nothing)
cv2.createTrackbar('VMin', 'image', 0, 255, nothing)
cv2.createTrackbar('HMax', 'image', 0, 179, nothing)
cv2.createTrackbar('SMax', 'image', 0, 255, nothing)
cv2.createTrackbar('VMax', 'image', 0, 255, nothing)

# Set default value for Max HSV trackbars
cv2.setTrackbarPos('HMax', 'image', 179)
cv2.setTrackbarPos('SMax', 'image', 255)
cv2.setTrackbarPos('VMax', 'image', 255)

# Initialize HSV min/max values
hMin = sMin = vMin = hMax = sMax = vMax = 0
phMin = psMin = pvMin = phMax = psMax = pvMax = 0

while(1):
    # Get current positions of all trackbars
    hMin = cv2.getTrackbarPos('HMin', 'image')
    sMin = cv2.getTrackbarPos('SMin', 'image')
    vMin = cv2.getTrackbarPos('VMin', 'image')
    hMax = cv2.getTrackbarPos('HMax', 'image')
    sMax = cv2.getTrackbarPos('SMax', 'image')
    vMax = cv2.getTrackbarPos('VMax', 'image')

    # Set minimum and maximum HSV values to display
    lower = np.array([hMin, sMin, vMin])
    upper = np.array([hMax, sMax, vMax])

    # Convert to HSV format and color threshold
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(hsv, lower, upper)
    result = cv2.bitwise_and(image, image, mask=mask)

    # Print if there is a change in HSV value
    if((phMin != hMin) | (psMin != sMin) | (pvMin != vMin) | (phMax != hMax) | (psMax != sMax) | (pvMax != vMax) ):
        print("(hMin = %d , sMin = %d, vMin = %d), (hMax = %d , sMax = %d, vMax = %d)" % (hMin , sMin , vMin, hMax, sMax , vMax))
        phMin = hMin
        psMin = sMin
        pvMin = vMin
        phMax = hMax
        psMax = sMax
        pvMax = vMax

    # Display result image
    cv2.imshow('image', result)
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()
# Out:
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 2 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 7 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 10 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 12 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 14 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 17 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 19 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 20 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 18 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 17 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 12 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 8 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 3 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 177 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 175 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 173 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 171 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 170 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 165 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 162 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 160 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 159 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 158 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 157 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 155 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 153 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 149 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 145 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 143 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 140 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 139 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 138 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 134 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 132 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 131 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 127 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 126 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 125 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 124 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 122 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 121 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 120 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 119 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 118 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 117 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 116 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 115 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 113 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 112 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 110 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 108 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 105 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 102 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 98 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 96 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 94 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 92 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 90 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 89 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 88 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 87 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 86 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 84 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 82 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 81 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 80 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 79 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 78 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 73 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 72 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 70 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 68 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 67 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 66 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 63 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 61 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 60 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 58 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 57 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 56 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 54 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 53 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 52 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 51 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 50 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 49 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 48 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 47 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 46 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 45 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 44 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 42 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 41 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 39 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 38 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 36 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 34 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 33 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 32 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 31 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 30 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 29 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 28 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 27 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 25 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 24 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 22 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 20 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 18 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 16 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 15 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 14 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 13 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 11 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 12 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 14 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 16 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 17 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 18 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 21 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 22 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 24 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 22 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 21 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 20 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 18 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 17 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 16 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 15 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 17 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 19 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 21 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 22 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 1 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 3 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 4 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 6 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 8 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 11 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 12 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 11 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 10 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 9 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 8 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 7 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 6 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 4 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 3 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 2 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 1 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 1 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 2 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 3 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 4 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 6 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 7 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 8 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 9 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 10 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 11 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 10 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 9 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 8 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 7 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 6 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 0, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 1, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 3, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 5, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 6, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 9, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 11, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 12, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 13, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 16, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 17, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 18, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 19, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 20, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 22, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 24, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 25, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 26, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 29, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 31, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 32, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 34, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 36, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 37, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 38, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 40, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 41, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 43, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 45, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 46, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 47, vMin = 0), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin =
vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 206, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 203, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 202, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 201, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 199, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 198, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 197, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 195, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 192, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 189, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 188, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 184, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 182, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 181, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 179, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 177, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 175, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 173, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 175, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 177, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 180, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 182, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 184, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 186, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 188, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 189, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 190, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 191, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 194, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 195, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 197, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 198, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 199, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 201, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 204, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 206, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 209, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 212, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 213, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 217, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 218, vMax = 255)
# ...
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 230, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 231, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 234, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 238, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 241, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 242, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 243, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 244, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 245, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 246, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 247, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 249, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 250, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 251, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 252, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 253, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 254, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 253)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 251)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 249)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 247)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 242)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 237)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 234)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 232)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 231)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 228)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 227)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 225)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 224)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 223)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 221)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 219)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 217)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 216)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 214)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 213)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 212)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 210)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 207)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 206)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 205)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 203)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 202)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 197)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 194)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 193)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 192)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 191)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 190)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 188)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 187)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 184)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 182)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 176)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 174)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 173)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 172)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 169)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 165)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 161)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 158)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 155)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 154)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 152)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 151)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 150)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 148)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 147)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 146)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 145)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 144)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 143)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 141)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 137)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 136)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 134)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 133)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 130)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 127)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 123)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 122)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 121)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 119)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 117)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 116)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 115)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 114)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 113)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 112)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 111)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 110)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 109)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 108)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 107)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 106)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 105)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 104)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 103)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 101)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 104)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 106)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 108)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 109)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 110)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 112)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 113)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 114)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 116)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 117)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 119)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 120)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 121)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 122)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 123)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 124)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 125)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 127)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 128)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 130)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 132)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 133)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 134)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 136)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 138)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 139)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 141)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 139)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 138)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 136)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 135)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 132)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 131)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 130)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 128)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 125)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 124)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 123)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 121)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 119)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 116)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 114)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 113)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 112)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 111)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 110)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 108)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 107)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 106)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 105)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 104)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 103)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 102)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 101)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 100)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 101)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 100)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 99)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 97)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 96)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 95)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 94)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 95)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 97)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 99)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 100)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 101)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 102)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 103)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 105)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 106)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 108)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 110)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 112)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 113)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 114)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 112)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 120)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 133)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 142)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 145)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 147)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 148)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 150)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 151)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 152)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 151)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 150)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 149)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 145)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 144)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 142)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 141)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 140)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 138)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 136)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 135)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 134)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 133)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 132)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 130)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 128)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 127)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 125)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 123)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 122)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 121)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 120)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 118)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 117)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 116)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 114)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 116)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 117)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 118)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 119)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 120)
# (hMin = 5 , sMin = 118, vMin = 54), (hMax = 23 , sMax = 255, vMax = 121)

# %%
#cv2.imshow('a',a)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
# Setup SimpleBlobDetector parameters.
params = cv2.SimpleBlobDetector_Params()

# Change thresholds
params.minThreshold = 10;
params.maxThreshold = 200;

# Filter by Area.
params.filterByArea = True
params.minArea = 500

# Filter by Circularity
params.filterByCircularity = True
params.minCircularity = 0.1

# Filter by Convexity
params.filterByConvexity = True
params.minConvexity = 0.87

# Filter by Inertia
params.filterByInertia = True
params.minInertiaRatio = 0.1

# Create a detector with the parameters
detector = cv2.SimpleBlobDetector_create(params)

# %%
#detector = cv2.SimpleBlobDetector()

# %%
#keypoints = detector.detect(a)

# %%
#detector = cv2.SimpleBlobDetector()

keypoints = detector.detect(a)

# Draw detected blobs as red circles.
# cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS ensures the size of the circle corresponds to the size of blob
im_with_keypoints = cv2.drawKeypoints(a, 
                                      keypoints, 
                                      np.array([]), 
                                      (0,0,255), 
                                      cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

# Show keypoints
cv2.imshow("Keypoints", im_with_keypoints)
cv2.waitKey(0)
cv2.destroyAllWindows()
